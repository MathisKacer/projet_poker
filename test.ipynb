# %%
from poker_parser import parse_file, parse_folder
import pandas as pd

# Un seul fichier
df = parse_file("fichier_test.txt")

# Tout un dossier
#df = parse_folder("dossier_test")

print(df.shape)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.head()

df.to_csv("tableau_mains.csv", index=False, encoding="utf-8")
# Out:
# (43, 28)
