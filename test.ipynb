# %%
from poker_parser import parse_file, parse_folder
import pandas as pd

# Un seul fichier
df = parse_file("fichier_test.txt")

# Tout un dossier
#df = parse_folder("historiques/")

print(df.shape)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.head()
# Out:
# (43, 30)
#   tournament  buy_in  level                           hand_id  sb_amount  \
# 0   Expresso    0.93      1  4707589644554862593-1-1776264090         10
# 1   Expresso    0.93      1  4707589644554862593-2-1776264122         10
# 2   Expresso    0.93      2  4707589644554862593-3-1776264198         15
# 3   Expresso    0.93      2  4707589644554862593-4-1776264220         15
# 4   Expresso    0.93      2  4707589644554862593-5-1776264230         15
#
#    bb_amount            datetime     hero  hero_seat  stack_start  \
# 0         20 2026-04-15 14:41:30  Samponi          2          500
# 1         20 2026-04-15 14:42:02  Samponi          2          480
# 2         30 2026-04-15 14:43:18  Samponi          2          686
# 3         30 2026-04-15 14:43:40  Samponi          2          731
# 4         30 2026-04-15 14:43:50  Samponi          2          746
#
#    total_players position  stack_bb hand_cards   vpip    pfr  fold_preflop  \
# 0              3       BB     25.00      8s 6c  False  False         False
# 1              3       SB     24.00      8s 9s   True  False         False
# 2              3      BTN     22.87      Kh 8h   True   True         False
# 3              3       BB     24.37      9c Kd  False  False         False
# 4              3       SB     24.87      3d 3s   True   True         False
#
#    allin_preflop      flop  turn river  saw_flop  saw_turn  saw_river  \
# 0          False  5c Qd 4c    3s    5s      True      True       True
# 1          False  9c Qs 8c    3s    2s      True      True       True
# 2          False      None  None  None     False     False      False
# 3          False      None  None  None     False     False      False
# 4          False  Ad 9c 5c    Qd    7d      True      True       True
#
#    went_to_showdown  won_at_showdown  total_pot  net_chips  net_bb  \
# 0              True            False        138        -20    -1.0
# 1              True             True        392        206    10.3
# 2             False            False        105         45     1.5
# 3             False            False         45         15     0.5
# 4              True             True        120         45     1.5
#
#         source_file
# 0  fichier_test.txt
# 1  fichier_test.txt
# 2  fichier_test.txt
# 3  fichier_test.txt
# 4  fichier_test.txt
