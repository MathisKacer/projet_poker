# %%
from poker_parser import parse_file, parse_folder
import pandas as pd

# Un seul fichier
#df = parse_file("fichier_test.txt")

# Tout un dossier
df = parse_folder("dossier_test")

print(df.shape)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.head()
# Out:
# 2 fichier(s) trouve(s)
#   20260415_Expresso(1096067975)_real_holdem_no-limit.txt -> 23 mains
#   20260415_Expresso(1096071127)_real_holdem_no-limit.txt -> 43 mains
#
# Total : 66 mains
# (66, 28)
#   tournament  buy_in  level                           hand_id  sb_amount  \
# 0   Expresso    0.93      1  4707576106817945601-1-1776263667         10
# 1   Expresso    0.93      1  4707576106817945601-2-1776263677         10
# 2   Expresso    0.93      1  4707576106817945601-3-1776263691         10
# 3   Expresso    0.93      1  4707576106817945601-4-1776263705         10
# 4   Expresso    0.93      1  4707576106817945601-5-1776263715         10
#
#    bb_amount            datetime     hero  hero_seat  stack_start  \
# 0         20 2026-04-15 14:34:27  Samponi          2          500
# 1         20 2026-04-15 14:34:37  Samponi          2          530
# 2         20 2026-04-15 14:34:51  Samponi          2           40
# 3         20 2026-04-15 14:35:05  Samponi          2           80
# 4         20 2026-04-15 14:35:15  Samponi          2          110
#
#    total_players position  stack_bb hand_cards  fold_preflop  allin_preflop  \
# 0              3      BTN      25.0      Ad Kc         False           True
# 1              3       BB      26.5      9c 9d         False           True
# 2              3       SB       2.0      4c 4s         False           True
# 3              3      BTN       4.0      Jh 9h         False           True
# 4              3       BB       5.5      2d 7s         False          False
#
#        flop  turn river  saw_flop  saw_turn  saw_river  went_to_showdown  \
# 0      None  None  None     False     False      False             False
# 1  5s Ts Td    Jd    3s      True      True       True              True
# 2  2s 8d Qd    Js    9d      True      True       True              True
# 3      None  None  None     False     False      False             False
# 4  Kh 2h Qh    3s    5h      True      True       True             False
#
#    won_at_showdown  total_pot  net_chips  net_bb  \
# 0            False        530         30     1.5
# 1             True       1030       -510   -25.5
# 2             True         80         30     1.5
# 3            False        110         30     1.5
# 4            False         60         20     1.0
#
#                                          source_file
# 0  20260415_Expresso(1096067975)_real_holdem_no-l...
# 1  20260415_Expresso(1096067975)_real_holdem_no-l...
# 2  20260415_Expresso(1096067975)_real_holdem_no-l...
# 3  20260415_Expresso(1096067975)_real_holdem_no-l...
# 4  20260415_Expresso(1096067975)_real_holdem_no-l...
