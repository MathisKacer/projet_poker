# %%
from poker_parser import parse_file, parse_folder
import pandas as pd

# Un seul fichier
df = parse_file("20260415_Expresso Nitro(1095916191)_real_holdem_no-limit.txt")

# Tout un dossier
#df = parse_folder("historiques/")

print(df.shape)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.head()
# Out:
# (10, 28)
#        tournament  buy_in  level                           hand_id  sb_amount  \
# 0  Expresso Nitro    0.93      1  4706924199501889537-1-1776239252         10
# 1  Expresso Nitro    0.93      1  4706924199501889537-2-1776239269         10
# 2  Expresso Nitro    0.93      1  4706924199501889537-3-1776239278         10
# 3  Expresso Nitro    0.93      1  4706924199501889537-4-1776239295         10
# 4  Expresso Nitro    0.93      1  4706924199501889537-5-1776239310         10
#
#    bb_amount            datetime  hero_seat  stack_start position  stack_bb  \
# 0         20 2026-04-15 07:47:32          3          300       SB      15.0
# 1         20 2026-04-15 07:47:49          3          600       SB      30.0
# 2         20 2026-04-15 07:47:58          3          580      BTN      29.0
# 3         20 2026-04-15 07:48:15          3          260       SB      13.0
# 4         20 2026-04-15 07:48:30          3          520      BTN      26.0
#
# ...
